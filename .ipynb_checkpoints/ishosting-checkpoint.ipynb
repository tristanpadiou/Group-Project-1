# %%
import pandas as pd
athlete_bio=pd.read_csv('files/Olympic_Athlete_Bio.csv')
athletes=pd.read_csv('files/Olympic_Athlete_Event_Results.csv')
country=pd.read_csv('files/Olympics_Games.csv')
olympics_medals=pd.read_csv('files/Olympic_Games_Medal_Tally.csv')
athletes
#looking at the data, we can see that the data is not clean, we have to clean it up
# Out:
#                      edition  edition_id country_noc      sport  \
# 0       1908 Summer Olympics           5         ANZ  Athletics
# 1       1908 Summer Olympics           5         ANZ  Athletics
# 2       1908 Summer Olympics           5         ANZ  Athletics
# 3       1908 Summer Olympics           5         ANZ  Athletics
# 4       1908 Summer Olympics           5         ANZ  Athletics
# ...                      ...         ...         ...        ...
# 316829  2022 Winter Olympics          62         NED  Bobsleigh
# 316830  2022 Winter Olympics          62         SVK  Bobsleigh
# 316831  2022 Winter Olympics          62         KOR  Bobsleigh
# 316832  2022 Winter Olympics          62         JAM  Bobsleigh
# 316833  2022 Winter Olympics          62         UKR  Bobsleigh
#
#                   event  result_id                     athlete  athlete_id  \
# 0       100 metres, Men      56265             Ernest Hutcheon       64710
# ...

# %%
athlete_bio
# Out:
#         athlete_id                name     sex               born  height  \
# 0            65649       Ivanka Bonova  Female       4 April 1949   166.0
# 1           112510   Nataliya Uryadova  Female      15 March 1977   184.0
# 2           114973  Essa Ismail Rashed    Male   14 December 1986   165.0
# 3            30359         Péter Boros    Male    12 January 1908     NaN
# 4            50557      Rudolf Piowatý    Male      28 April 1900     NaN
# ...            ...                 ...     ...                ...     ...
# 155856       23748         Todd Makler    Male     8 January 1946   183.0
# 155857       58581        Géza Hollósi    Male         2 May 1938   175.0
# 155858       30387  József Keresztessy    Male  19 September 1885     NaN
# 155859       69900    Alexander Thieme    Male    13 January 1954   187.0
# 155860       74003         Sunday Bada    Male       22 June 1969   188.0
#
#        weight              country country_noc  \
# ...

# %%
#looking for null values in the data
# Out:
# athlete_id            0
# name                  0
# sex                   0
# born               4053
# height            50749
# weight            50749
# country               0
# country_noc           0
# description      100998
# special_notes     95224
# dtype: int64

# %%
hosting=country.loc[country['year']>1990].sort_values('year',ascending=True).reset_index(drop=True)
hosting
# Out:
#                  edition  edition_id    edition_url  year  \
# 0   1992 Summer Olympics          23   /editions/23  1992
# 1   1992 Winter Olympics          44   /editions/44  1992
# 2   1994 Winter Olympics          45   /editions/45  1994
# 3   1996 Summer Olympics          24   /editions/24  1996
# 4   1998 Winter Olympics          46   /editions/46  1998
# 5   2000 Summer Olympics          25   /editions/25  2000
# 6   2002 Winter Olympics          47   /editions/47  2002
# 7   2004 Summer Olympics          26   /editions/26  2004
# 8   2006 Winter Olympics          49   /editions/49  2006
# 9   2008 Summer Olympics          53   /editions/53  2008
# 10  2010 Winter Olympics          57   /editions/57  2010
# 11  2012 Summer Olympics          54   /editions/54  2012
# 12  2014 Winter Olympics          58   /editions/58  2014
# 13  2016 Summer Olympics          59   /editions/59  2016
# 14  2018 Winter Olympics          60   /editions/60  2018
# ...

# %%
olympics_medals
# Out:
#                    edition  edition_id  year                     country  \
# 1293  2020 Summer Olympics          61  2020                     Ukraine
# 1294  2020 Summer Olympics          61  2020                     Belarus
# 1295  2020 Summer Olympics          61  2020                     Romania
# 1296  2020 Summer Olympics          61  2020                   Venezuela
# 1297  2020 Summer Olympics          61  2020                       India
# 1298  2020 Summer Olympics          61  2020            Hong Kong, China
# 1299  2020 Summer Olympics          61  2020                 Philippines
# 1300  2020 Summer Olympics          61  2020                    Slovakia
# 1285  2020 Summer Olympics          61  2020                      Greece
# 1301  2020 Summer Olympics          61  2020                South Africa
# 1302  2020 Summer Olympics          61  2020                     Austria
# 1303  2020 Summer Olympics          61  2020                       Egypt
# ...

# %%
#figuring out the average number of participants per country over the years
numberofparticipants=athletes.loc[athletes['edition']>'1990']
numbergroup=numberofparticipants.groupby('country_noc')['athlete'].count().reset_index()
numbergroup
# Out:
#     country_noc  athlete
# 0           AFG       25
# 1           AHO       29
# 2           ALB       83
# 3           ALG      450
# 4           AND      151
# ..          ...      ...
# 210         VIN       41
# 211         YEM       40
# 212         YUG       60
# 213         ZAM       86
# 214         ZIM      157
#
# [215 rows x 2 columns]
