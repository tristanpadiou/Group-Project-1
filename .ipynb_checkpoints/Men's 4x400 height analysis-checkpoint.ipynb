# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Olympic_Athlete_Bio_df = pd.read_csv("files/Olympic_Athlete_Bio.csv")
Olympic_Athlete_Event_Results_df = pd.read_csv("files/Olympic_Athlete_Event_Results.csv")
Olympic_Games_Medal_Tally_df = pd.read_csv("files/Olympic_Games_Medal_Tally.csv")
Olympic_Results_df = pd.read_csv("files/Olympic_Results.csv")
Olympics_Country_df = pd.read_csv("files/Olympics_Country.csv")
Olympics_Games_df = pd.read_csv("files/Olympics_Games.csv")

# %%
Olympic_Athlete_Bio_df.head()
# Out:
#    athlete_id                name     sex              born  height weight  \
# 0       65649       Ivanka Bonova  Female      4 April 1949   166.0     55
# 1      112510   Nataliya Uryadova  Female     15 March 1977   184.0     70
# 2      114973  Essa Ismail Rashed    Male  14 December 1986   165.0     55
# 3       30359         Péter Boros    Male   12 January 1908     NaN    NaN
# 4       50557      Rudolf Piowatý    Male     28 April 1900     NaN    NaN
#
#                country country_noc  \
# 0             Bulgaria         BUL
# 1   Russian Federation         RUS
# 2                Qatar         QAT
# 3              Hungary         HUN
# 4       Czechoslovakia         TCH
#
#                                          description  \
# 0                 Personal Best: 400 – 53.54 (1980).
# 1                                                NaN
# 2            Personal Best: 10000 – 27:20.97 (2006).
# 3  Between 1927 and 1938, Péter Boros competed as...
# 4  Rudolf Piowaty joined the Czechoslovak militar...
#
#                                        special_notes
# 0                                                NaN
# 1  Listed in Olympians Who Won a Medal at the Eur...
# 2  Listed in Olympians Who Won a Medal at the Asi...
# 3                                                NaN
# 4                                                NaN

# %%
Merged_df = pd.merge(Olympic_Athlete_Bio_df, Olympic_Athlete_Event_Results_df, on="athlete_id")
Merged_df.head()
# Out:
#    athlete_id                name     sex              born  height weight  \
# 0       65649       Ivanka Bonova  Female      4 April 1949   166.0     55
# 1       65649       Ivanka Bonova  Female      4 April 1949   166.0     55
# 2      112510   Nataliya Uryadova  Female     15 March 1977   184.0     70
# 3      114973  Essa Ismail Rashed    Male  14 December 1986   165.0     55
# 4       30359         Péter Boros    Male   12 January 1908     NaN    NaN
#
#                country country_noc_x  \
# 0             Bulgaria           BUL
# 1             Bulgaria           BUL
# 2   Russian Federation           RUS
# 3                Qatar           QAT
# 4              Hungary           HUN
#
#                                          description  \
# 0                 Personal Best: 400 – 53.54 (1980).
# 1                 Personal Best: 400 – 53.54 (1980).
# 2                                                NaN
# 3            Personal Best: 10000 – 27:20.97 (2006).
# 4  Between 1927 and 1938, Péter Boros competed as...
#
#                                        special_notes               edition  \
# 0                                                NaN  1976 Summer Olympics
# 1                                                NaN  1980 Summer Olympics
# 2  Listed in Olympians Who Won a Medal at the Eur...  2008 Summer Olympics
# 3  Listed in Olympians Who Won a Medal at the Asi...  2008 Summer Olympics
# 4                                                NaN  1932 Summer Olympics
#
#    edition_id country_noc_y                sport                        event  \
# 0          19           BUL            Athletics  4 × 400 metres Relay, Women
# 1          20           BUL            Athletics  4 × 400 metres Relay, Women
# 2          53           RUS     Beach Volleyball      Beach Volleyball, Women
# 3          53           QAT            Athletics           10,000 metres, Men
# 4          10           HUN  Artistic Gymnastics   Individual All-Around, Men
#
#    result_id             athlete        pos medal  isTeamSport
# 0      62051       Ivanka Bonova  5 h2 r1/2   NaN         True
# 1      62530       Ivanka Bonova    AC r2/2   NaN         True
# 2     258676   Nataliya Uryadova        =19   NaN         True
# 3     257228  Essa Ismail Rashed         20   NaN        False
# 4      70092         Péter Boros         19   NaN        False

# %%
Merged_df1 = Merged_df[["athlete_id", "height", "weight", "event", "medal"]]
Merged_df1
# Out:
#         athlete_id  height weight                        event medal
# 0            65649   166.0     55  4 × 400 metres Relay, Women   NaN
# 1            65649   166.0     55  4 × 400 metres Relay, Women   NaN
# 2           112510   184.0     70      Beach Volleyball, Women   NaN
# 3           114973   165.0     55           10,000 metres, Men   NaN
# 4            30359     NaN    NaN   Individual All-Around, Men   NaN
# ...            ...     ...    ...                          ...   ...
# 316822       74003   188.0     79    4 × 400 metres Relay, Men   NaN
# 316823       74003   188.0     79              400 metres, Men   NaN
# 316824       74003   188.0     79    4 × 400 metres Relay, Men   NaN
# 316825       74003   188.0     79              400 metres, Men   NaN
# 316826       74003   188.0     79    4 × 400 metres Relay, Men  Gold
#
# [316827 rows x 5 columns]

# %%
Merged_df2 = Merged_df1[Merged_df1["event"] == "400 metres, Men"]
Merged_df2
# Out:
#         athlete_id  height weight            event medal
# 270          75623   178.0     70  400 metres, Men   NaN
# 346          65572   176.0     74  400 metres, Men   NaN
# 348          65572   176.0     74  400 metres, Men   NaN
# 446          65610   185.0     73  400 metres, Men   NaN
# 508         132635   193.0     94  400 metres, Men   NaN
# ...            ...     ...    ...              ...   ...
# 316019       73242     NaN    NaN  400 metres, Men   NaN
# 316250       70319   187.0     83  400 metres, Men   NaN
# 316821       74003   188.0     79  400 metres, Men   NaN
# 316823       74003   188.0     79  400 metres, Men   NaN
# 316825       74003   188.0     79  400 metres, Men   NaN
#
# [1709 rows x 5 columns]

# %%
height_cleaned_df = Merged_df2.dropna(subset=['height'])
height_cleaned_df.set_index("athlete_id")

weight_cleaned_df = Merged_df2.dropna(subset=['weight'])
weight_cleaned_df.set_index("athlete_id")
# Out:
#             height weight            event medal
# athlete_id
# 75623        178.0     70  400 metres, Men   NaN
# 65572        176.0     74  400 metres, Men   NaN
# 65572        176.0     74  400 metres, Men   NaN
# 65610        185.0     73  400 metres, Men   NaN
# 132635       193.0     94  400 metres, Men   NaN
# ...            ...    ...              ...   ...
# 65225        178.0     75  400 metres, Men   NaN
# 70319        187.0     83  400 metres, Men   NaN
# 74003        188.0     79  400 metres, Men   NaN
# 74003        188.0     79  400 metres, Men   NaN
# 74003        188.0     79  400 metres, Men   NaN
#
# [1247 rows x 4 columns]

# %%
weight_cleaned_df = Merged_df2.dropna(subset=['weight'])
weight_cleaned_df.set_index("athlete_id")
# Out:
#             height weight            event medal
# athlete_id
# 75623        178.0     70  400 metres, Men   NaN
# 65572        176.0     74  400 metres, Men   NaN
# 65572        176.0     74  400 metres, Men   NaN
# 65610        185.0     73  400 metres, Men   NaN
# 132635       193.0     94  400 metres, Men   NaN
# ...            ...    ...              ...   ...
# 65225        178.0     75  400 metres, Men   NaN
# 70319        187.0     83  400 metres, Men   NaN
# 74003        188.0     79  400 metres, Men   NaN
# 74003        188.0     79  400 metres, Men   NaN
# 74003        188.0     79  400 metres, Men   NaN
#
# [1247 rows x 4 columns]

# %%
Gold_height_df = height_cleaned_df[height_cleaned_df["medal"] == "Gold"]
Silver_height_df = height_cleaned_df[height_cleaned_df["medal"] == "Silver"]
Bronze_height_df = height_cleaned_df[height_cleaned_df["medal"] == "Bronze"]

No_Medal_height_df = height_cleaned_df[height_cleaned_df["medal"] != "Gold"]
No_Medal_height_df1 = height_cleaned_df[height_cleaned_df["medal"] != "Silver"]
No_Medal_height_df2 = height_cleaned_df[height_cleaned_df["medal"] != "Bronze"]

# %%
Gold_weight_df = weight_cleaned_df[weight_cleaned_df["medal"] == "Gold"]
Silver_weight_df = weight_cleaned_df[weight_cleaned_df["medal"] == "Silver"]
Bronze_weight_df = weight_cleaned_df[weight_cleaned_df["medal"] == "Bronze"]

No_Medal_weight_df = weight_cleaned_df[weight_cleaned_df["medal"] != "Gold"]
No_Medal_weight_df1 = weight_cleaned_df[weight_cleaned_df["medal"] != "Silver"]
No_Medal_weight_df2 = weight_cleaned_df[weight_cleaned_df["medal"] != "Bronze"]

# %%
Gold_height_df.head(2)
# Out:
#        athlete_id  height weight            event medal
# 510        132635   193.0     94  400 metres, Men  Gold
# 11786      115006   191.0     86  400 metres, Men  Gold

# %%
Gold_weight_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28 entries, 510 to 304554
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   athlete_id  28 non-null     int64
#  1   height      28 non-null     float64
#  2   weight      28 non-null     object
#  3   event       28 non-null     object
#  4   medal       28 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.3+ KB

# %%
Gold_weight_df['weight'] = Gold_weight_df['weight'].astype(int)
Silver_weight_df['weight'] = Silver_weight_df['weight'].astype(int)
Bronze_weight_df['weight'] = Bronze_weight_df['weight'].astype(int)
# Out:
# C:\Users\jandr\AppData\Local\Temp\ipykernel_14448\693206648.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Gold_weight_df['weight'] = Gold_weight_df['weight'].astype(int)
# C:\Users\jandr\AppData\Local\Temp\ipykernel_14448\693206648.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Silver_weight_df['weight'] = Silver_weight_df['weight'].astype(int)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 3
#       1 Gold_weight_df['weight'] = Gold_weight_df['weight'].astype(int)
#       2 Silver_weight_df['weight'] = Silver_weight_df['weight'].astype(int)
# ----> 3 Bronze_weight_df['weight'] = Bronze_weight_df['weight'].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or arr.dtype == object or dtype == object:
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '70-74'

# %%
Bronze_weight_df['weight'] = Bronze_weight_df['weight'].astype(int)
No_Medal_weight_df2['weight'] = No_Medal_weight_df2['weight'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 Bronze_weight_df['weight'] = Bronze_weight_df['weight'].astype(int)
#       2 No_Medal_weight_df2['weight'] = No_Medal_weight_df2['weight'].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or arr.dtype == object or dtype == object:
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '70-74'

# %%
Silver_height_df.head(2)
# Out:
#        athlete_id  height weight            event   medal
# 10028      105653   185.0     83  400 metres, Men  Silver
# 39793       70178   180.0     68  400 metres, Men  Silver

# %%
Bronze_height_df.head(2)
# Out:
#        athlete_id  height weight            event   medal
# 11790      115006   191.0     86  400 metres, Men  Bronze
# 36484      125965   179.0     83  400 metres, Men  Bronze

# %%
No_Medal_height_df.head(2)
# Out:
#      athlete_id  height weight            event medal
# 270       75623   178.0     70  400 metres, Men   NaN
# 346       65572   176.0     74  400 metres, Men   NaN

# %%
No_Medal_height_df2.head(2)
# Out:
#      athlete_id  height weight            event medal
# 270       75623   178.0     70  400 metres, Men   NaN
# 346       65572   176.0     74  400 metres, Men   NaN

# %%
Gold_height_df.plot(kind='kde', x='athlete_id', y='height')
plt.xlabel('Height (CM)')
plt.title('Gold Medal Winners')
plt.xlim(160, 200)
plt.ylim(-0.01, 0.08)
plt.show()

Silver_height_df.plot(kind='kde', x='athlete_id', y='height')
plt.xlabel('Height (CM)')
plt.title('Silver Medal Winners')
plt.xlim(160, 200)
plt.ylim(-0.01, 0.08)
plt.show()

Bronze_height_df.plot(kind='kde', x='athlete_id', y='height')
plt.xlabel('Height (CM)')
plt.title('Bronze Medal Winners')
plt.xlim(160, 200)
plt.ylim(-0.01, 0.08)
plt.show()

No_Medal_height_df2.plot(kind='kde', x='athlete_id', y='height')
plt.xlabel('Height (CM)')
plt.title('No Medal')
plt.xlim(160, 200)
plt.ylim(-0.01, 0.08)
plt.show()

# %%
Gold_weight_df.plot(kind='kde', x='athlete_id', y='weight')
plt.xlabel('Weight (KG)')
plt.title('Gold Medal Winners')
plt.show()

Silver_weight_df.plot(kind='kde', x='athlete_id', y='weight')
plt.xlabel('Weight (KG)')
plt.title('Silver Medal Winners')
plt.show()

Bronze_weight_df.plot(kind='kde', x='athlete_id', y='weight')
plt.xlabel('Weight (KG)')
plt.title('Bronze Medal Winners')
plt.show()

No_Medal_weight_df2.plot(kind='kde', x='athlete_id', y='weight')
plt.xlabel('Weight (KG)')
plt.title('No Medal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 Gold_weight_df.plot(kind='kde', x='athlete_id', y='weight')
#       2 plt.xlabel('Weight (KG)')
#       3 plt.title('Gold Medal Winners')
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:451, in MPLPlot.generate(self)
#     449 def generate(self) -> None:
#     450     self._args_adjust()
# --> 451     self._compute_plot_data()
#     452     self._setup_subplots()
#     453     self._make_plot()
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:636, in MPLPlot._compute_plot_data(self)
#     634 # no non-numeric frames or series allowed
#     635 if is_empty:
# --> 636     raise TypeError("no numeric data to plot")
#     638 self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot
