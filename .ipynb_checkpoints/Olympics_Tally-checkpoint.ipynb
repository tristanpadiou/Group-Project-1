# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#create relevant dataframes for analysis:

#dataframe showing country codes
df_country = pd.read_csv('files/Olympics_Country.csv')

#dataframe showing all the Summer Games info
df_games = pd.read_csv('files/Olympics_Games.csv')
df_games_summer =df_games.loc[df_games['edition'].str.contains('Summer')]

# data base of medal tally for all olympic games, from 1896 to 2020
df_tally = pd.read_csv('files/Olympic_Games_Medal_Tally.csv')

# %%
df_tally.head()
# Out:
#                 edition  edition_id  year        country country_noc  gold  \
# 0  1896 Summer Olympics           1  1896  United States         USA    11
# 1  1896 Summer Olympics           1  1896         Greece         GRE    10
# 2  1896 Summer Olympics           1  1896        Germany         GER     6
# 3  1896 Summer Olympics           1  1896         France         FRA     5
# 4  1896 Summer Olympics           1  1896  Great Britain         GBR     2
#
#    silver  bronze  total
# 0       7       2     20
# 1      18      19     47
# 2       5       2     13
# 3       4       2     11
# 4       3       2      7

# %%
#identify host countries for all the Summer Games
df_games_summer =df_games_summer.drop(["edition_id","edition_url",'country_flag_url','start_date','end_date', 'competition_date'],axis=1)
df_games_summer = df_games_summer.rename(columns = {'country_noc':'noc','city': 'host city'})

#add a column of hose country names by merging with df_country dataset
df_games_summer = pd.merge(df_games_summer, df_country, on="noc", how="left")

#rename and reorder the dataset to be more easily understandable
df_games_summer = df_games_summer.rename(columns = {'country':'host country'})
columns = ['edition', 'year','host city', 'host country','noc', 'isHeld']
df_games_summer = df_games_summer[columns]

df_games_summer
# Out:
#                  edition  year         host city                host country  \
# 0   1896 Summer Olympics  1896            Athina                      Greece
# 1   1900 Summer Olympics  1900             Paris                      France
# 2   1904 Summer Olympics  1904         St. Louis               United States
# 3   1908 Summer Olympics  1908            London               Great Britain
# 4   1912 Summer Olympics  1912         Stockholm                      Sweden
# 5   1916 Summer Olympics  1916            Berlin                     Germany
# 6   1920 Summer Olympics  1920         Antwerpen                     Belgium
# 7   1924 Summer Olympics  1924             Paris                      France
# 8   1928 Summer Olympics  1928         Amsterdam                 Netherlands
# 9   1932 Summer Olympics  1932       Los Angeles               United States
# 10  1936 Summer Olympics  1936            Berlin                     Germany
# ...

# %%
#Identify countries that hosted the most number of Summer Games
df_host_country_summer=df_games_summer[['edition','host country']]
df_host_country_summer['host country'].value_counts()
# Out:
# host country
# United States                 5
# Great Britain                 4
# Australia                     3
# France                        3
# Greece                        2
# Germany                       2
# Finland                       2
# Japan                         2
# Canada                        1
# People's Republic of China    1
# Spain                         1
# Republic of Korea             1
# Soviet Union                  1
# Italy                         1
# West Germany                  1
# Mexico                        1
# Netherlands                   1
# Belgium                       1
# Sweden                        1
# Brazil                        1
# Name: count, dtype: int64

# %%
df_host_country_summer.describe()
# Out:
#                      edition   host country
# count                     35             35
# unique                    35             20
# top     1896 Summer Olympics  United States
# freq                       1              5

# %%
print(f"There have been 35 Summmer Olympic Games held frm 1896 to 2024")
print(f"The 35 Summer Games have been hosted by 20 different countries")
# Out:
# There have been 35 Summmer Olympic Games held frm 1896 to 2024
# The 35 Summer Games have been hosted by 20 different countries

# %%
# Focus on metal tally for all Summer Olympic Games only, from 1896 to 2020
summer_tally =  df_tally[df_tally['edition'].str.contains('Summer')]
summer_tally
# Out:
#                    edition  edition_id  year               country  \
# 0     1896 Summer Olympics           1  1896         United States
# 1     1896 Summer Olympics           1  1896                Greece
# 2     1896 Summer Olympics           1  1896               Germany
# 3     1896 Summer Olympics           1  1896                France
# 4     1896 Summer Olympics           1  1896         Great Britain
# ...                    ...         ...   ...                   ...
# 1338  2020 Summer Olympics          61  2020                 Ghana
# 1339  2020 Summer Olympics          61  2020               Grenada
# 1340  2020 Summer Olympics          61  2020                Kuwait
# 1341  2020 Summer Olympics          61  2020   Republic of Moldova
# 1342  2020 Summer Olympics          61  2020  Syrian Arab Republic
#
#      country_noc  gold  silver  bronze  total
# 0            USA    11       7       2     20
# 1            GRE    10      18      19     47
# ...

# %%
#calculate total medals by year
total_medals_by_year = summer_tally.groupby('year')[['gold','silver','bronze','total']].sum().reset_index()
total_medals_by_year = total_medals_by_year.rename(columns={'total':'total full game'})
total_medals_by_year
#merge total medal counts to summer_tally dataframe
summer_tally = pd.merge(summer_tally, total_medals_by_year, on='year',how='left')
summer_tally
# Out:
#                    edition  edition_id  year               country  \
# 0     1896 Summer Olympics           1  1896         United States
# 1     1896 Summer Olympics           1  1896                Greece
# 2     1896 Summer Olympics           1  1896               Germany
# 3     1896 Summer Olympics           1  1896                France
# 4     1896 Summer Olympics           1  1896         Great Britain
# ...                    ...         ...   ...                   ...
# 1338  2020 Summer Olympics          61  2020                 Ghana
# 1339  2020 Summer Olympics          61  2020               Grenada
# 1340  2020 Summer Olympics          61  2020                Kuwait
# 1341  2020 Summer Olympics          61  2020   Republic of Moldova
# 1342  2020 Summer Olympics          61  2020  Syrian Arab Republic
#
#      country_noc  gold_x  silver_x  bronze_x  total  gold_y  silver_y  \
# 0            USA      11         7         2     20      43        43
# ...

# %%
#rename columns names
summer_tally = summer_tally.rename(columns = {"country_noc":"noc",
                                             "gold_x":"country_gold",
                                             "silver_x":"country_silver",
                                             "bronze_x":"country_bronze",
                                             "total":"country_total",
                                             "gold_y":"game_gold",
                                             "silver_y":"game_silver",
                                             "bronze_y":"game_bronze",
                                             "total full game":"game_total"})
summer_tally
# Out:
#                    edition  edition_id  year               country  noc  \
# 0     1896 Summer Olympics           1  1896         United States  USA
# 1     1896 Summer Olympics           1  1896                Greece  GRE
# 2     1896 Summer Olympics           1  1896               Germany  GER
# 3     1896 Summer Olympics           1  1896                France  FRA
# 4     1896 Summer Olympics           1  1896         Great Britain  GBR
# ...                    ...         ...   ...                   ...  ...
# 1338  2020 Summer Olympics          61  2020                 Ghana  GHA
# 1339  2020 Summer Olympics          61  2020               Grenada  GRN
# 1340  2020 Summer Olympics          61  2020                Kuwait  KUW
# 1341  2020 Summer Olympics          61  2020   Republic of Moldova  MDA
# 1342  2020 Summer Olympics          61  2020  Syrian Arab Republic  SYR
#
#       country_gold  country_silver  country_bronze  country_total  game_gold  \
# ...

# %%
#add a column calculating the percentage of total medal count by country to the total medal count of the entire game
summer_tally["country_medal_percentage"] = summer_tally['country_total']/summer_tally['game_total']* 100
summer_tally
# Out:
#                    edition  edition_id  year               country  noc  \
# 0     1896 Summer Olympics           1  1896         United States  USA
# 1     1896 Summer Olympics           1  1896                Greece  GRE
# 2     1896 Summer Olympics           1  1896               Germany  GER
# 3     1896 Summer Olympics           1  1896                France  FRA
# 4     1896 Summer Olympics           1  1896         Great Britain  GBR
# ...                    ...         ...   ...                   ...  ...
# 1338  2020 Summer Olympics          61  2020                 Ghana  GHA
# 1339  2020 Summer Olympics          61  2020               Grenada  GRN
# 1340  2020 Summer Olympics          61  2020                Kuwait  KUW
# 1341  2020 Summer Olympics          61  2020   Republic of Moldova  MDA
# 1342  2020 Summer Olympics          61  2020  Syrian Arab Republic  SYR
#
#       country_gold  country_silver  country_bronze  country_total  game_gold  \
# ...

# %%
#create a metal tally for USA only for Summer Olympics Gamees
USA_summer_tally = summer_tally[summer_tally['noc']=="USA"]
USA_summer_tally
# Out:
#                    edition  edition_id  year        country  noc  \
# 0     1896 Summer Olympics           1  1896  United States  USA
# 12    1900 Summer Olympics           2  1900  United States  USA
# 30    1904 Summer Olympics           3  1904  United States  USA
# 39    1908 Summer Olympics           5  1908  United States  USA
# 57    1912 Summer Olympics           6  1912  United States  USA
# 76    1920 Summer Olympics           7  1920  United States  USA
# 98    1924 Summer Olympics           8  1924  United States  USA
# 129   1928 Summer Olympics           9  1928  United States  USA
# 163   1932 Summer Olympics          10  1932  United States  USA
# 192   1936 Summer Olympics          11  1936  United States  USA
# 223   1948 Summer Olympics          12  1948  United States  USA
# 261   1952 Summer Olympics          13  1952  United States  USA
# 305   1956 Summer Olympics          14  1956  United States  USA
# ...

# %%
# number of metals USA has won in each of the summer games
USA_summer_medal_trend = summer_tally[summer_tally['country'] == 'United States'].set_index('year')['country_total']
USA_summer_medal_trend
# Out:
# year
# 1896     20
# 1900     48
# 1904    248
# 1908     47
# 1912     64
# 1920     95
# 1924     99
# 1928     56
# 1932    110
# 1936     57
# 1948     84
# 1952     76
# 1956     74
# 1960     71
# 1964     90
# 1968    107
# 1972     94
# 1976     94
# 1984    174
# 1988     94
# 1992    108
# 1996    101
# 2000     93
# 2004    101
# 2008    112
# 2012    104
# 2016    121
# 2020    113
# Name: country_total, dtype: int64

# %%
#Plot medal counts by type won by USA in all Summer Games
plt.figure(figsize=(16, 8))
plt.bar(USA_summer_tally['year'], USA_summer_tally['country_bronze'], label='Bronze', color='#cd7f32')
plt.bar(USA_summer_tally['year'], USA_summer_tally['country_silver'], bottom=USA_summer_tally['country_bronze'], label='Silver', color='silver')
plt.bar(USA_summer_tally['year'], USA_summer_tally['country_gold'], bottom=USA_summer_tally['country_bronze'] + USA_summer_tally['country_silver'], label='Gold', color='gold')

plt.title('Proportion of Medal Types Across the Years (USA)')
plt.xlabel('Year')
plt.ylabel('Number of Medals')

# Trend of US metal in summer Olympics over time
USA_summer_medal_trend.plot(kind='line', linewidth=0.5, linestyle='--',figsize=(12, 6),color='b',
                            title='United States Medal Trend (Total Metal Count) Over Time in Summer Olympics', ylabel='Total Medal Count', xlabel='Year', label="USA medal count")

plt.xticks(USA_summer_tally['year'], rotation=90)
plt.legend(loc='upper right')
plt.show()

# %%
# Trend of US metal in summer Olympics over time
USA_summer_medal_trend.plot(kind='line', marker='o', figsize=(16, 8), color='b',
                            title='USA Summer Olympics Medal trend: Total Count', ylabel='Total Medal Count', xlabel='Year', label="USA medal count")


# Set x-ticks to match the years in your data
plt.xticks(USA_summer_medal_trend.index, rotation=90)

# Add vertical lines for specific years
#US_host_years = [1904, 1932, 1984, 1996]  # Years where you want vertical lines
#for year in specific_years:
#    plt.axvline(x=year, color='red', linestyle='--', linewidth=1)

# Highlight intersection points at specific years
usa_host_years = [1904, 1932, 1984, 1996]
usa_host_medals = USA_summer_medal_trend.loc[usa_host_years]  # Get the medal counts for these years

plt.scatter(usa_host_years, usa_host_medals, color='b', s=200, zorder=20, alpha=0.4, label="USA host years")  # Highlight points

plt.grid(color='gray', linewidth=0.4)
plt.xticks(summer_tally['year'], rotation=90)
# Display the plot
plt.legend(loc='best')
plt.show()

# %%
# percentage of of metals USA has won in comparison total metals awarded in each of the summer games
USA_summer_medal_percentage = summer_tally[summer_tally['country'] == 'United States'].set_index('year')['country_medal_percentage']
USA_summer_medal_percentage
# Out:
# year
# 1896    16.393443
# 1900    16.901408
# 1904    88.571429
# 1908    14.506173
# 1912    20.189274
# 1920    21.158129
# 1924    25.255102
# 1928    15.730337
# 1932    29.729730
# 1936    13.507109
# 1948    18.961625
# 1952    16.557734
# 1956    16.407982
# 1960    15.401302
# 1964    17.857143
# 1968    20.303605
# 1972    15.666667
# 1976    15.334421
# 1984    25.290698
# 1988    12.719892
# 1992    13.251534
# 1996    11.995249
# 2000    10.032362
# 2004    10.907127
# 2008    11.691023
# 2012    10.833333
# 2016    12.448560
# 2020    10.462963
# Name: country_medal_percentage, dtype: float64

# %%
# Trend of US medal percentage in summer Olympics over time
USA_summer_medal_percentage.plot(kind='line', marker='o', figsize=(16, 8), title='United States Medal Trend (% of total medals)', ylabel='Percentage of metals won', xlabel='Year', color='green', label='% of US medals')
plt.grid(linewidth=0.4)
plt.xticks(summer_tally['year'], rotation=90)

# Highlight intersection points at specific years
usa_host_years = [1904, 1932, 1984, 1996]
usa_host_medal_percent = USA_summer_medal_percentage.loc[usa_host_years]  # Get the medal percent for these years
plt.scatter(usa_host_years, usa_host_medal_percent, color='green', s=200, zorder=20, alpha=0.4, label="USA host years")  # Highlight points

# Display the plot
plt.legend(loc='best')
plt.show()

# %%
# Compare US medal trends in terms of total medal count versus percentage of metals to total awarded at the game
USA_summer_medal_trend.plot(kind='line', marker='o', figsize=(16,8), color='b',
                            ylabel='Total Medal Count', xlabel='Year', label="USA medal count")

# Trend of US medal percentage in summer Olympics over time
USA_summer_medal_percentage.plot(kind='line', marker='o', 
                                 title='United States Medal Trend: Total count vs Percentage to entire game)', 
                                 ylabel='Medal count/percentage', xlabel='Year', color='green', label='% of US medals')

# Highlight intersection points at specific years
usa_host_years = [1904, 1932, 1984, 1996]
usa_host_medals = USA_summer_medal_trend.loc[usa_host_years]  # Get the medal counts for these years
plt.scatter(usa_host_years, usa_host_medals, color='b', s=200, zorder=20, alpha=0.4, label="USA host years")  # Highlight points

# Highlight intersection points at specific years
usa_host_medal_percent = USA_summer_medal_percentage.loc[usa_host_years]  # Get the medal percent for these years
plt.scatter(usa_host_years, usa_host_medal_percent, color='green', s=200, zorder=20, alpha=0.4)  # Highlight points

# Display the plot
plt.grid(color='gray', linewidth=0.4)
plt.xticks(summer_tally['year'], rotation=90)
plt.legend(loc='best')
plt.show()

# %%
# how many countries have won medals in each of the Summer Games?
country_counts =summer_tally.groupby('edition')['noc'].nunique().reset_index()
country_counts
# Out:
#                  edition  noc
# 0   1896 Summer Olympics   11
# 1   1900 Summer Olympics   19
# 2   1904 Summer Olympics    8
# 3   1908 Summer Olympics   19
# 4   1912 Summer Olympics   19
# 5   1920 Summer Olympics   22
# 6   1924 Summer Olympics   31
# 7   1928 Summer Olympics   34
# 8   1932 Summer Olympics   28
# 9   1936 Summer Olympics   32
# 10  1948 Summer Olympics   38
# 11  1952 Summer Olympics   43
# 12  1956 Summer Olympics   37
# 13  1960 Summer Olympics   44
# 14  1964 Summer Olympics   41
# 15  1968 Summer Olympics   44
# 16  1972 Summer Olympics   48
# 17  1976 Summer Olympics   41
# 18  1980 Summer Olympics   36
# 19  1984 Summer Olympics   47
# 20  1988 Summer Olympics   52
# 21  1992 Summer Olympics   64
# 22  1996 Summer Olympics   79
# 23  2000 Summer Olympics   80
# 24  2004 Summer Olympics   74
# 25  2008 Summer Olympics   87
# 26  2012 Summer Olympics   86
# 27  2016 Summer Olympics   86
# 28  2020 Summer Olympics   93

# %%
#how many Summer games did each of these countries held?
host_country_summer = df_games_summer['noc'].value_counts()
host_country_summer
# Out:
# noc
# USA    5
# GBR    4
# AUS    3
# FRA    3
# GRE    2
# GER    2
# FIN    2
# JPN    2
# CAN    1
# CHN    1
# ESP    1
# KOR    1
# URS    1
# ITA    1
# FRG    1
# MEX    1
# NED    1
# BEL    1
# SWE    1
# BRA    1
# Name: count, dtype: int64

# %%
#create a new dataset focusing on the top 8 countries that hosted the summer games the most 
top_summer_hosts = ['USA','GBR','AUS','FRA','GRE',"GER",'FIN','JPN']
top_summer_hosts_tally =summer_tally[summer_tally['noc'].isin(top_summer_hosts)]
top_summer_hosts_tally.head(50)
# Out:
#                   edition  edition_id  year        country  noc  country_gold  \
# 0    1896 Summer Olympics           1  1896  United States  USA            11
# 1    1896 Summer Olympics           1  1896         Greece  GRE            10
# 2    1896 Summer Olympics           1  1896        Germany  GER             6
# 3    1896 Summer Olympics           1  1896         France  FRA             5
# 4    1896 Summer Olympics           1  1896  Great Britain  GBR             2
# 7    1896 Summer Olympics           1  1896      Australia  AUS             2
# 11   1900 Summer Olympics           2  1900         France  FRA            31
# 12   1900 Summer Olympics           2  1900  United States  USA            20
# 13   1900 Summer Olympics           2  1900  Great Britain  GBR            20
# 16   1900 Summer Olympics           2  1900        Germany  GER             4
# 28   1900 Summer Olympics           2  1900      Australia  AUS             0
# ...

# %%
#Group by country and aggregate the years
summer_host_years = df_games_summer.groupby('noc')['year'].apply(list).reset_index()
#Sort by country
summer_host_years = summer_host_years.sort_values(by='year')
summer_host_years
# Out:
#     noc                            year
# 11  GRE                    [1896, 2004]
# 7   FRA              [1900, 1924, 2024]
# 19  USA  [1904, 1932, 1984, 1996, 2028]
# 9   GBR        [1908, 1944, 1948, 2012]
# 17  SWE                          [1912]
# 10  GER                    [1916, 1936]
# 1   BEL                          [1920]
# 16  NED                          [1928]
# 6   FIN                    [1940, 1952]
# 0   AUS              [1956, 2000, 2032]
# 12  ITA                          [1960]
# 13  JPN                    [1964, 2020]
# 15  MEX                          [1968]
# 8   FRG                          [1972]
# 3   CAN                          [1976]
# 18  URS                          [1980]
# 14  KOR                          [1988]
# 5   ESP                          [1992]
# 4   CHN                          [2008]
# 2   BRA                          [2016]

# %%
#plot trends of total numbers of medals won by the top countries
summer_tally[summer_tally['country'] == 'United States'].set_index('year')['country_total'].plot(color='b', figsize=(16,8),label="USA")
summer_tally[summer_tally['country'] == 'Great Britain'].set_index('year')['country_total'].plot(color='r',label="UK")
summer_tally[summer_tally['country'] == 'Australia'].set_index('year')['country_total'].plot(color='green',label="Australia")
summer_tally[summer_tally['country'] == 'France'].set_index('year')['country_total'].plot(color='orange',label="France")
summer_tally[summer_tally['country'] == 'Greece'].set_index('year')['country_total'].plot(color='lightblue',label="Greece")
#summer_tally[summer_tally['country'] == 'Germany'].set_index('year')['country_total'].plot(label="Germany")
#summer_tally[summer_tally['country'] == 'Finland'].set_index('year')['country_total'].plot(label="Finland")
#summer_tally[summer_tally['country'] == 'Japan'].set_index('year')['country_total'].plot(label="Japan")


# Highlight intersection points at specific years
usa_host_years = [1904, 1932, 1984, 1996]
usa_host_medals = USA_summer_medal_trend.loc[usa_host_years]  # Get the medal counts for these years
plt.scatter(usa_host_years, usa_host_medals, color='b', s=50, zorder=20, alpha=0.8, label="USA host year")

#highlight Great Britain host years on graph
gbr_host_years = [1908, 1944, 1948, 2012]
gbr_host_medals = summer_tally[(summer_tally['country'] == 'Great Britain') & (summer_tally['year'].isin(gbr_host_years))]
plt.scatter(gbr_host_medals['year'], gbr_host_medals['country_total'], color='r', s=50, zorder=20, alpha=0.8,label="UK host year")

#highlight Australia host years on graph
aus_host_years = [1956, 2000]
aus_host_medals = summer_tally[(summer_tally['country'] == 'Australia') & (summer_tally['year'].isin(aus_host_years))]
plt.scatter(aus_host_medals['year'], aus_host_medals['country_total'], color='green', s=50, zorder=20, alpha=0.8,label="Australia host year")

#highlight France host years on graph
fra_host_years = [1900, 1924]
fra_host_medals = summer_tally[(summer_tally['country'] == 'France') & (summer_tally['year'].isin(fra_host_years))]
plt.scatter(fra_host_medals['year'], fra_host_medals['country_total'], color='orange', s=50, zorder=20, alpha=0.8,label="France host year")

#highlight Greece host years on graph
gre_host_years = [1896, 2004]
gre_host_medals = summer_tally[(summer_tally['country'] == 'Greece') & (summer_tally['year'].isin(gre_host_years))]
plt.scatter(gre_host_medals['year'], gre_host_medals['country_total'], color='lightblue', s=50, zorder=20, alpha=0.8,label="Greece host year")



plt.title('Total Number of Medals by the top 5 most frequent host countries')
plt.legend(loc="best")
plt.grid(color='gray',linewidth=0.4)
plt.xticks(summer_tally['year'], rotation=90)
plt.show()

# %%
# Define the countries, colors, and host years
countries = ['United States', 'Great Britain', 'Australia', 'France', 'Greece','Germany','Finland','Japan']
colors = ['b', 'r', 'green', 'orange', 'lightblue','brown','darkblue','purple']
host_years = {
    'United States': [1904, 1932, 1984, 1996],
    'Great Britain': [1908, 1944, 1948, 2012],
    'Australia': [1956, 2000],
    'France': [1900, 1924],
    'Greece': [1896, 2004],
    'Germany':[1916, 1936],
    'Finland':[1940,1952],
    'Japan':[1964,2020]
}

# Plot trends for each country
for country, color in zip(countries, colors):
    summer_tally[summer_tally['country'] == country].set_index('year')['country_total'].plot(color=color, figsize=(16,8), label=country)

    # Highlight host years
    host_years_country = host_years[country]
    host_medals = summer_tally[(summer_tally['country'] == country) & (summer_tally['year'].isin(host_years_country))]
    plt.scatter(host_medals['year'], host_medals['country_total'], color=color, s=50, zorder=20, alpha=0.8, label=f"{country} host year")

plt.title('Total Number of Medals by the Top 5 Most Frequent Host Countries')
plt.legend(loc="upper right")
plt.grid(color='gray', linewidth=0.4)
plt.xticks(summer_tally['year'], rotation=90)
plt.show()

# %%
#plot trends of percentage of medals won by the top countries
summer_tally[summer_tally['country'] == 'United States'].set_index('year')['country_medal_percentage'].plot(figsize=(12,6),label="USA")
summer_tally[summer_tally['country'] == 'Great Britain'].set_index('year')['country_medal_percentage'].plot(label="Great Britain")
summer_tally[summer_tally['country'] == 'Australia'].set_index('year')['country_medal_percentage'].plot(label="Australia")
summer_tally[summer_tally['country'] == 'France'].set_index('year')['country_medal_percentage'].plot(label="France")
summer_tally[summer_tally['country'] == 'Greece'].set_index('year')['country_medal_percentage'].plot(label="Greece")
summer_tally[summer_tally['country'] == 'Germany'].set_index('year')['country_medal_percentage'].plot(label="Germany")
summer_tally[summer_tally['country'] == 'Finland'].set_index('year')['country_medal_percentage'].plot(label="Finland")
summer_tally[summer_tally['country'] == 'Japan'].set_index('year')['country_medal_percentage'].plot(label="Japan")
plt.title('Percentage of medtals won by the top host countries of Summer Olympic Games')
plt.xticks(summer_tally['year'], rotation=90)
plt.legend(loc="best")
plt.grid(color='gray', linewidth=0.4)
plt.show()

# %%
# Out:
#     noc                            year
# 0   AUS              [1956, 2000, 2032]
# 1   BEL                          [1920]
# 2   BRA                          [2016]
# 3   CAN                          [1976]
# 4   CHN                          [2008]
# 5   ESP                          [1992]
# 6   FIN                    [1940, 1952]
# 7   FRA              [1900, 1924, 2024]
# 8   FRG                          [1972]
# 9   GBR        [1908, 1944, 1948, 2012]
# 10  GER                    [1916, 1936]
# 11  GRE                    [1896, 2004]
# 12  ITA                          [1960]
# 13  JPN                    [1964, 2020]
# 14  KOR                          [1988]
# 15  MEX                          [1968]
# 16  NED                          [1928]
# 17  SWE                          [1912]
# 18  URS                          [1980]
# 19  USA  [1904, 1932, 1984, 1996, 2028]
