# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_country = pd.read_csv('files/Olympics_Country.csv')

# %%
# data base of medal tally for all olympic games
df_tally = pd.read_csv('files/Olympic_Games_Medal_Tally.csv')

# %%
#Create a medal tally for only Summer Olympics games
summer_tally =  df_tally[df_tally['edition'].str.contains('Summer')]
summer_tally.head(50)
# Out:
#                  edition  edition_id  year             country country_noc  \
# 0   1896 Summer Olympics           1  1896       United States         USA
# 1   1896 Summer Olympics           1  1896              Greece         GRE
# 2   1896 Summer Olympics           1  1896             Germany         GER
# 3   1896 Summer Olympics           1  1896              France         FRA
# 4   1896 Summer Olympics           1  1896       Great Britain         GBR
# 5   1896 Summer Olympics           1  1896             Hungary         HUN
# 6   1896 Summer Olympics           1  1896             Austria         AUT
# 7   1896 Summer Olympics           1  1896           Australia         AUS
# 8   1896 Summer Olympics           1  1896             Denmark         DEN
# 9   1896 Summer Olympics           1  1896         Switzerland         SUI
# 10  1896 Summer Olympics           1  1896          Mixed team         MIX
# ...

# %%
#create a new dataset focusing on the top 8 countries that hosted the summer games the most 
top_summer_hosts = ['USA','GBR','AUS','FRA','GRE',"GER",'FIN','JPN']
top_summer_hosts_tally = df_tally[df_tally['country_noc'].isin(top_summer_hosts)]
top_summer_hosts_tally.head(50)
# Out:
#                   edition  edition_id  year        country country_noc  gold  \
# 0    1896 Summer Olympics           1  1896  United States         USA    11
# 1    1896 Summer Olympics           1  1896         Greece         GRE    10
# 2    1896 Summer Olympics           1  1896        Germany         GER     6
# 3    1896 Summer Olympics           1  1896         France         FRA     5
# 4    1896 Summer Olympics           1  1896  Great Britain         GBR     2
# 7    1896 Summer Olympics           1  1896      Australia         AUS     2
# 11   1900 Summer Olympics           2  1900         France         FRA    31
# 12   1900 Summer Olympics           2  1900  United States         USA    20
# 13   1900 Summer Olympics           2  1900  Great Britain         GBR    20
# 16   1900 Summer Olympics           2  1900        Germany         GER     4
# 28   1900 Summer Olympics           2  1900      Australia         AUS     0
# ...

# %%
# pivot the data into the correct shape
df = top_summer_hosts_tally.pivot(index='year', columns='country', values='total')
# plot the pivoted dataframe; if the column names aren't colors, remove color=df.columns
df.plot(color=df.columns, figsize=(5, 3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 # pivot the data into the correct shape
# ----> 2 df = top_summer_hosts_tally.pivot(index='year', columns='country', values='total')
#       3 # plot the pivoted dataframe; if the column names aren't colors, remove color=df.columns
#       4 df.plot(color=df.columns, figsize=(5, 3))
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:9339, in DataFrame.pivot(self, columns, index, values)
#    9332 @Substitution("")
#    9333 @Appender(_shared_docs["pivot"])
#    9334 def pivot(
#    9335     self, *, columns, index=lib.no_default, values=lib.no_default
#    9336 ) -> DataFrame:
#    9337     from pandas.core.reshape.pivot import pivot
# -> 9339     return pivot(self, index=index, columns=columns, values=values)
#
# ...

# %%
#create a metal tally for USA only for Summer Olympics Gamees
USA_summer_tally = summer_tally[summer_tally['country_noc']=="USA"]
USA_summer_tally

# %%
# number of metals USA has won in each of the summer games
USA_summer_medal_trend = summer_tally[summer_tally['country'] == 'United States'].set_index('year')['total']
USA_summer_medal_trend
# Out:
# year
# 1896     20
# 1900     48
# 1904    248
# 1908     47
# 1912     64
# 1920     95
# 1924     99
# 1928     56
# 1932    110
# 1936     57
# 1948     84
# 1952     76
# 1956     74
# 1960     71
# 1964     90
# 1968    107
# 1972     94
# 1976     94
# 1984    174
# 1988     94
# 1992    108
# 1996    101
# 2000     93
# 2004    101
# 2008    112
# 2012    104
# 2016    121
# 2020    113
# Name: total, dtype: int64

# %%
summer_tally[summer_tally['country'] == 'United States'].set_index('year')['total'].plot()
summer_tally[summer_tally['country'] == 'France'].set_index('year')['total'].plot()
summer_tally[summer_tally['country'] == 'Germany'].set_index('year')['total'].plot()
# Out:
# <Axes: xlabel='year'>

# %%
# Trend of US metal in summer Olympics over time
USA_summer_medal_trend.plot(kind='line', marker='o', figsize=(12, 6), title='United States Medal Trend Over Time in Summer Olympics', ylabel='Total Medals', xlabel='Year')
# Out:
# <Axes: title={'center': 'United States Medal Trend Over Time in Summer Olympics'}, xlabel='Year', ylabel='Total Medals'>

# %%
top.plot(kind='line', marker='o', figsize=(12, 6), title='United States Medal Trend Over Time in Summer Olympics', ylabel='Total Medals', xlabel='Year')

# %%
# Plotting the stacked bar chart
plt.figure(figsize=(14, 8))
plt.bar(USA_summer_tally['year'], USA_summer_tally['gold'], label='Gold', color='gold')
plt.bar(USA_summer_tally['year'], USA_summer_tally['silver'], bottom=USA_summer_tally['gold'], label='Silver', color='silver')
plt.bar(USA_summer_tally['year'], USA_summer_tally['bronze'], bottom=USA_summer_tally['gold'] + USA_summer_tally['silver'], label='Bronze', color='#cd7f32')

plt.title('Proportion of Medal Types Across the Years (USA)')
plt.xlabel('Year')
plt.ylabel('Number of Medals')
plt.legend(loc='upper right')
plt.xticks(rotation=45)
plt.show()

# %%
# Plotting the stacked bar chart winter
plt.figure(figsize=(14, 8))
plt.bar(USA_winter_tally['year'], USA_winter_tally['gold'], label='Gold', color='gold')
plt.bar(USA_winter_tally['year'], USA_winter_tally['silver'], bottom=USA_winter_tally['gold'], label='Silver', color='silver')
plt.bar(USA_winter_tally['year'], USA_winter_tally['bronze'], bottom=USA_winter_tally['gold'] + USA_winter_tally['silver'], label='Bronze', color='#cd7f32')

plt.title('Proportion of Medal Types Across the Years in Winter Olympics (USA)')
plt.xlabel('Year')
plt.ylabel('Number of Medals')
plt.legend(loc='upper right')
plt.xticks(rotation=45)
plt.show()

# %%
#histogram
plt.figure(figsize=(12, 6))
plt.hist(USA_summer_tally['total'], bins=10, color='skyblue', edgecolor='black')
plt.title('Distribution of Total Medals Won by the United States')
plt.xlabel('Total Medals')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %%
#how to identify top 5 countries for summer games
# Group by country and sum the total medals
medals_summary = summer_olympics_tally.groupby('country').agg(total_medals=('total', 'sum')).reset_index()

# Sort the results by total medals in descending order
top_countries = medals_summary.sort_values(by='total_medals', ascending=False).head(5)

# Display the top 5 countries
print(top_countries)

# %%
# Group by year and country, then sum total medals
medals_by_country = summer_tally.groupby(['year', 'country']).agg(total_medals=('total', 'sum')).reset_index()

# Calculate the average total medals for each country
average_medals = medals_by_country.groupby('country').agg(avg_medals=('total_medals', 'mean')).reset_index()

# Sort countries by average total medals in descending order
consistent_performers = average_medals.sort_values(by='avg_medals', ascending=False)

# Display the top countries with the highest average medal counts
print(consistent_performers)
